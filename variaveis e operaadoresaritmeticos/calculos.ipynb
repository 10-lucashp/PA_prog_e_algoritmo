# %% [markdown]
# Exercicio Carro

# %%
##Entrada
precodefabrica = float(input("Digite o preço de fabrica do carro: "))
imposto = float(input("Digite o imposto em porcentagem:  "))
distribuicao = float(input("Digite a porcentagem de taxa de distribuição:  "))
# Out:
# Digite o preço de fabrica do carro: 1500
# Digite o imposto em porcentagem:  32
# Digite a porcentagem de taxa de distribuição:  11

# %%
##Calculo
precofinal = imposto = (precodefabrica *imposto/100) + precodefabrica
precofinal =distribuicao = (imposto + distribuicao/100)

# %%
##Resultado
print(f"O preço final do carro é: {precofinal}")
# Out:
# O preço final do carro é: 159688691.0

# %% [markdown]
# Exercicio horas e minutos

# %%
##entrada
horas = float(input("Digite as horas: "))
minutos= float(input("Digite os minutos: "))
# Out:
# Digite as horas: 2
# Digite os minutos: 12

# %%
##calculo
segundos = (minutos/60)+horas

# %%
##resultado
print(f"Os segundos são: {segundos}")
# Out:
# Os segundos são: 2.2

# %% [markdown]
# Exercicio hora extra

# %%
##entrada
hr = float(input("digite as horas : "))
mn = float(input(" digite quantos minutos ele trabalhou: "))
vh = float(input("digite o valor por hora : "))
# Out:
# digite as horas : 3
#  digite quantos minutos ele trabalhou: 45
# digite o valor por hora : 40

# %%
##calculo
conversao = hr + (mn/60)
salario = (conversao * vh)

# %%
#resultado
print(f"O salario de hora extra é: {salario}")
# Out:
# O salario de hora extra é: 150.0
